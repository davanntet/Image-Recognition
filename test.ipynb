# %%
from skimage import exposure
from skimage.feature import hog
from glob import glob
import cv2
from matplotlib import pyplot as plt

# %%
cat_files = glob("c:/Data/data/animals/animals/cat/*.jpg")

# %%
img = cv2.imread(cat_files[9])

# %%
plt.imshow(img)

# %%
_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(_img, cmap='gray')

# %%
import numpy as np

# %%
_,mask = cv2.threshold(_img, 200, 255, cv2.THRESH_BINARY_INV)

# %%
plt.imshow(mask, cmap='gray')

# %%
mask_inv = cv2.bitwise_not(mask)

# %%
result = cv2.bitwise_and(img, img, mask=mask_inv)

# %%
plt.imshow(result)

# %%
image = cv2.imread(cat_files[9])

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to create a mask
_, mask = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY)

# Invert the mask
mask_inv = cv2.bitwise_not(mask)

# Apply the mask to the image
result = cv2.bitwise_and(image, image, mask=mask_inv)

# Display the result
cv2.imshow('Original Image', image)
cv2.imshow('Background Removed', result)
